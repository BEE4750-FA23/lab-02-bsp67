# %% [markdown]
# # BEE 4750 Lab 2: Uncertainty and Monte Carlo

# %% [markdown]
# **Name**: Brooke Paykin
#
# **ID**: Bsp67

# %% [markdown]
# > **Due Date**
# >
# > Friday, 9/22/23, 9:00pm
#
# ## Setup
#
# The following code should go at the top of most Julia scripts; it will
# load the local package environment and install any needed packages. You
# will see this often and shouldn’t need to touch it.

# %%
import Pkg
Pkg.activate(".")
Pkg.instantiate()
# Out:
#   Activating project at `~/github-classroom/BEE4750-FA23/lab-02-bsp67`

# %%
using Random # random number generation
using Distributions # probability distributions and interface
using Statistics # basic statistical functions, including mean
using Plots # plotting

# %% [markdown]
# ## Introduction
#
# In this lab, you will use Monte Carlo analysis to estimate the expected
# winnings for a couple of different games of chance.
#
# Monte Carlo methods involve the simulation of random numbers from
# probability distributions. In an environmental context, we often
# propagate these random numbers through some more complicated model and
# then compute a resulting statistic which is relevant for assessing
# performance or risk, such as an average outcome or a particular
# quantile.
#
# Julia provides a common interface for probability distributions with the
# [`Distributions.jl`
# package](https://juliastats.org/Distributions.jl/stable/). The basic
# workflow for sampling from a distribution is:
#
# 1.  Set up the distribution. The specific syntax depends on the
#     distribution and what parameters are required, but the general call
#     is the similar. For a normal distribution or a uniform distribution,
#     the syntax is
#
#     ``` julia
#     # you don't have to name this "normal_distribution"
#     # μ is the mean and σ is the standard deviation
#     normal_distribution = Normal(μ, σ)
#     # a is the upper bound and b is the lower bound; these can be set to +Inf or -Inf for an unbounded distribution in one or both directions.
#     uniform_distribution = Uniform(a, b)
#     ```
#
#     There are lots of both
#     [univariate](https://juliastats.org/Distributions.jl/stable/univariate/#Index)
#     and
#     [multivariate](https://juliastats.org/Distributions.jl/stable/multivariate/)
#     distributions, as well as the ability to create your own, but we
#     won’t do anything too exotic here.
#
# 2.  Draw samples. This uses the `rand()` command (which, when used
#     without a distribution, just samples uniformly from the interval
#     $[0, 1]$.) For example, to sample from our normal distribution
#     above:
#
#     ``` julia
#     # draw n samples
#     rand(normal_distribution, n)
#     ```
#
# Putting this together, let’s say that we wanted to simulate 100
# six-sided dice rolls. We could use a [Discrete Uniform
# distribution](https://juliastats.org/Distributions.jl/stable/univariate/#Distributions.DiscreteUniform).

# %%
dice_dist = DiscreteUniform(1, 6) # can generate any integer between 1 and 6
dice_rolls = rand(dice_dist, 100) # simulate rolls
# Out:
# 100-element Vector{Int64}:
#  2
#  2
#  5
#  3
#  1
#  2
#  5
#  2
#  4
#  1
#  ⋮
#  6
#  6
#  4
#  3
#  2
#  1
#  4
#  1
#  5

# %% [markdown]
# And then we can plot a histogram of these rolls:

# %%
histogram(dice_rolls, legend=:false, bins=6)
ylabel!("Count")
xlabel!("Dice Value")

# %% [markdown]
# **Remember to**:
#
# -   Evaluate all of your code cells, in order (using a `Run All`
#     command). This will make sure all output is visible and that the
#     code cells were evaluated in the correct order.
# -   Tag each of the problems when you submit to Gradescope; a 10%
#     penalty will be deducted if this is not done.

# %% [markdown]
# ## Exercises (10 points)
#
# In Problem 1, you will compute the probability of getting a specific
# combination of multiple dice rolls. The focus will be on understanding
# how the Monte Carlo estimate changes based on the number of simulations.
#
# In Problem 2, we will implement the culmination of every episode of the
# long-running game show [The Price Is
# Right](https://en.wikipedia.org/wiki/The_Price_Is_Right): the
# [Showcase](https://en.wikipedia.org/wiki/The_Price_Is_Right#Showcase).
# You will be asked to make a plot of expected winnings by bid for a
# particular distribution of prize values.
#
# You should always start any computing with random numbers by setting a
# “seed,” which controls the sequence of numbers which are generated
# (since these are not *really* random, just “pseudorandom”). In Julia, we
# do this with the `Random.seed!()` function.
#
# ``` julia
# Random.seed!(1)
# ```
#
#     TaskLocalRNG()
#
# It doesn’t matter what seed you set, though different seeds might result
# in slightly different values. But setting a seed means every time your
# notebook is run, the answer will be the same.
#
# > **Seeds and Reproducing Solutions**
# >
# > If you don’t re-run your code in the same order or if you re-run the
# > same cell repeatedly, you will not get the same solution. If you’re
# > working on a specific problem, you might want to re-use
# > `Random.seed()` near any block of code you want to re-evaluate
# > repeatedly.

# %% [markdown]
# ### Problem 1 (5 points)
#
# We want to know the probability of getting at least an 11 from rolling
# three fair, six-sided dice (this is actually an old Italian game called
# *passadieci*, which was analyzed by Galileo as one of the first examples
# of a rigorous study of probability).

# %% [markdown]
# #### Problem 1.1 (1 point)
#
# Write a function called `passadieci()` to simulate this game, which will
# take as an input the number of realizations and output a vector of the
# sum of the three dice rolls for each realization.

# %%
using Random

# %%
function passadieci(num_realizations)
    @assert num_realizations>=0 #num_realizations is the number of time you roll 3 fair six sided 
    #dice AKA play the game
    game = 0 #will be used to keep track of # of games played
    realizationtotals = []
    Random.seed!(13) #random integer chosen
    while num_realizations > game
        dice_dist = DiscreteUniform(1, 6) # can generate any integer between 1 and 6
        dice_rolls = rand(dice_dist, 3) # simulate rolls
        sumofgame = sum(dice_rolls)#NOW sum up each vector in dice roll
        push!(realizationtotals, sumofgame) #now append the sum to realization totals
        game += 1 #add 1 to show that 1 more game has been played
    end
return realizationtotals #return the realization totals 
end
# Out:
# passadieci (generic function with 1 method)

# %% [markdown]
# ### Problem 1.2 (2 points)
#
# Generate 5,000 simulations of the game using your `passadieci()`
# function. Plot how the computed probability of winning the game changes
# as the number of simulations increases (you can do this by computing the
# frequency of wins for each additional simulation).

# %%
function didyouwin(gamesplayed)
    results = passadieci(gamesplayed)
    x = 1
    probabilitiesofwinningXamountofgames = []  # Store probabilities for different 
    #numbers of games played
    
    while x <= gamesplayed #x is an index variable to make sure it goes through 
        #all simulations
        wincounts = []  # Reset wincounts for each simulation
        
        dummycounterofgames = 1 #this will make it so that we can account 
        #past simulation results
        for dummycounterofgames in 1:x
            individualgamescore = results[dummycounterofgames] #this finds total score 
            #of game
            
            if individualgamescore >= 11
                push!(wincounts, 1) #add 1 for each game that was won
            else
                push!(wincounts, 0) #do not add anything for each game lost
            end
        end

        #probability is calculated by doing number of winning simulations divided by
        #number of simulations run overall
        probabilityofwinningXamountofgames_x = sum(wincounts) / x 
        #probabilities are appended to create big array of probabilities 
        push!(probabilitiesofwinningXamountofgames, probabilityofwinningXamountofgames_x)
        x += 1 #tally is increased
    end
    
    #plot with labels
    plot(1:gamesplayed, probabilitiesofwinningXamountofgames, xlabel="Games Played", ylabel="Probability of Winning", title="Probability of winning passadieci")
    
end
# Out:
# didyouwin (generic function with 1 method)

# %%
didyouwin(5000)

# %% [markdown]
# ### Problem 1.3 (2 point)
#
# Based on your plot from Problem 1.2, how many simulations were needed
# for the win probability estimate to converge? What did you notice from
# your plot about the estimates prior to convergence?

# %% [markdown]
# Approximately 800 simulations were needed for the probability estimates to converge. I noticed from my plot that there is a lot of fluctuation when there are fewer simulations, but the amplitude of the flucutaion decreases as more simulations are run.Moreover, the probability skyrockets to 1 when there are few games played (apprxoimately 1), but then never reaches anywhere near that peak again.

# %% [markdown]
# ## Problem 2 (5 points)
#
# The Showcase is the final round of every episode of The Price is Right,
# matching the two big winners from the episode. Each contestant is shown
# a “showcase” of prizes, which are usually some combination of a trip, a
# motor vehicle, some furniture, and maybe some other stuff. They then
# each have to make a bid on the retail price of the showcase. The rules
# are:
#
# -   an overbid is an automatic loss;
# -   the contest who gets closest to the retail price wins their
#     showcase;
# -   if a contestant gets within \$250 of the retail price and is closer
#     than their opponent, they win both showcases.
#
# Your goal is to find a wager which maximizes your expected winnings,
# which we may as well call utility, based on your assessment of the
# probability of your showcase retail price. We’ll assume that the
# distribution of all showcases offered by the show is given as truncated
# normal distribution, which means a normal distribution which has an
# upper and/or lower bound. `Distributions.jl` makes it easy to specify
# truncations on any distribution, not just normal distributions. For
# example, we’ll use this distribution for the showcase values:
#
# ``` julia
# showcase_dist = truncated(Normal(31000, 4500), lower=5000, upper=42000)
# ```
#
#     Truncated(Normal{Float64}(μ=31000.0, σ=4500.0); lower=5000.0, upper=42000.0)

# %% [markdown]
# #### Problem 2.1 (3 points)
#
# Write a function `showcase()` which takes in a bid value and uses Monte
# Carlo simulation to compute the expected value of the winnings. Make the
# following assumptions about your expected winnings if you don’t overbid:
#
# -   If you win both showcases, the value is the double of the single
#     showcase value.
# -   If you did not win both showcases but bid under the showcase value,
#     the probability of being outbid increases linearly as the distance
#     between your bid and the value increases (in other words, if you bid
#     the exact value, you win with probability 1, and if you bid \$0, you
#     win with probability 0).
#
# How did you decide how many samples to use within the function?

# %%
using Distributions
using Random

# %%
function showcase(bid_value)
    showcase_dist = truncated(Normal(31000, 4500), lower=5000, upper=42000)
    total_winnings = 0.0
    samplesize = 250 # Random initial sample size

    # I want a 95% chance that I would win something
    # I want to be 95% confident in my final answer, so I will keep calculating samples
    # until my error falls at or below 5%, which will be represented as error = 0.05. This
    # is how I will determine sample size, based on my error.
    current_error = 1.0 # Starting with a random large error so that I can reduce it later
    desired_error = 0.05 # My desired error of 5%
    winnings = 0.0
    previous_winnings = 0.0
    expected_winnings = 0.0

    while current_error > desired_error
        winnings = 0.0 # Reset winnings for each iteration

        dummycounterofgames = 1 #this will make it so that we can account 
        #past simulation results
        for dummycounterofgames in 1:samplesize#get a data point for each sample

            real_showcase_amount = rand(showcase_dist) # The true value of the showcase amount for
            # current trial. Must pick a new random amount for each trial 

            if bid_value > real_showcase_amount # Scenario 1, contestant overbids
                continue  # Skip if overbid  
            elseif real_showcase_amount - bid_value <= 250 # You come within 250 of true value 
                # and do not overbid, scenario 2
                winnings = 2 * real_showcase_amount # Win both showcases 
                # which is value at 2x the true value
            else #other, scenario 3
                probabilitywin = (bid_value / real_showcase_amount)
                # Probability should scale linearly based on true value - bid
                # If you bid half of the true value, you win/lose with probability 0.5
                #this is equivalent to saying that u win 1/2 that money, so thats how im doing math
                winnings = probabilitywin * real_showcase_amount
            end

            #the reason for this if statement is that u cant have a previous estimate if it is trial 1
            #so this ensures there is a previous so that u can use it to update the current error
            if dummycounterofgames > 1
                previous_estimated_winnings = winnings
                #error is how far apart guesses are from each other
                current_error = abs((winnings - previous_estimated_winnings) / winnings)
            end

            dummycounterofgames += 1
            #Dynamically adjust the sample size for the next iteration based on the error
            samplesize += Int(ceil(samplesize * 0.1)) # Increase sample size by 10% rounding up 
            #to nearest interger
        end


    end

    println("Expected Winnings:", winnings)
    println("Final Sample Size:", samplesize)
    println("Current error:", current_error)
end
# Out:
# showcase (generic function with 1 method)

# %%
function showcase(bid_value)
    showcase_dist = truncated(Normal(31000, 4500), lower=5000, upper=42000) 
    #given disturbution for showcase values is showcase_dist
    
    winnings = 0.00 #start off by winning 0$ and 0 cents
    samplesize = 250 #random inital sample size
    Random.seed!(13) #random integer chosen, to keep simulation consistentwinnings = 0.00

    #i want a 95% chance that i would win something
    ##i want to be 95% confident in my final answer, so i will keep calculating samples
    #until my error falls at or below 5% which will be represented as error = 0.05. this
    #is how i will determine sample size, based off my error
    currenterror = 1 #starting with random large error so that i can reduce it later
    desirederror = 0.05 #my desired error of 5%

    while currenterror > desirederror
        total_winnings = 0.0  # Reset total_winnings for each iteration
        
        dummycounterofgames = 1 #this will make it so that we can account 
        #past simulation results
        for dummycounterofgames in 1:samplesize#get a data point for each sample
            real_showcase_amount = rand(showcase_dist)  #the true value of the 
            #showcase amount
            
            if bid_value > real_showcase_amount #scenario 1, contestent overbids
                continue  # Skip if overbid
            end
            
            if real_showcase_amount - bid_value <= 250 #you come within 250 of true value 
                #and do not overbid, scenario 2
                winnings = 2 * real_showcase_amount#win both showcases 
                #which is value at 2x the true value
            else
                probabilitywin = 1 - (bid_value / real_showcase_amount)
                #probability should scale linearly based on true value - bid
                #If you bid half of the true value, you win/lose with probability 0.5
                winnings = probabilitywin * real_showcase_amount
            end
            
            total_winnings += winnings #add winnings
            dummycounterofgames += 1
        
        expected_winnings = total_winnings / samplesize #monte carlo estimate 
        #of expected value, aka the winnings per game
        
        #calculate relative error of monte carlo estimate (expected winnings) 
        #relative to itself. this will be current error
        current_error = abs(expected_winnings - real_showcase_amount) / expected_winnings
        samplesize += 50
        end
    end
    final_sample_size = samplesize - 50
    estimated_winnings = total_winnings / final_sample_size
    
    println("Expected Winnings:", estimated_winnings)
    println("Final Sample Size:", final_sample_size)
    println("Current error:", currenterror)
end
# Out:
# showcase (generic function with 1 method)

# %% [markdown]
# none of this code for question 2 is doing what i want it too and im big sad about it:( )
#
# the first code says my error is always 0, and no matter what inital guess i put it, it tells me i will earn that amount. which is just plain false
#
# my second code makes an infinite loop
#
# ive also done code that iterate right and it wont converge to 1 nmber no matter how many times i run it it will keep changing. and moreover, the code sample size is stagment which makes no sense bc that is literally the point of the prompt. my sample size should choose itself but it wont and its big sad
#
#
#
# so basically i will not win any money on a game show bc my guess system is bad and i am big sad :()

# %% [markdown]
# I decided how many samples to use in the function by my error. I wanted to be 95% confident so I kept increasing the sample size until my error fell below (or at) 5%.
#
# I had two error variables. One was initally set to be large and was called current error. the other was my goal error, 5%. I kept iterating until my current error fell below (or at) 5%.
#
# I could not do Estimated Number – Actual Number)/ Actual number because I have no true value to compare to. In the monte carlo simulation, i measure my error between my estimated value and reference value. My estimated value is expected winnings. My known value is actual winnings.
#
# I found current error by finding the absolute difference between estimated value and reference value, and then dividing it by my expected value.
#
# Essentially, I measured how far off my estimate was from itself.
#
# If my error was greater than 5%, I increased my sample size.
#
# I did not want to start with too large a sample size because that would be slow for my computer to calculate. I did not want my sample size to be too small and have such a large error that i couldn't trust it. That is how I decided my sample size.

# %% [markdown]
# #### Problem 2.2 (2 points)
#
# Plot the expected winnings for bids ranging from \$0 to \$42,000. What
# do you notice?

# %% [markdown]
# ## References
#
# Put any consulted sources here, including classmates you worked with/who
# helped you.
